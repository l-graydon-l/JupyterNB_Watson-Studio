# %% [markdown]
# # H1 "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Graydon Wetzler**
# Jupyter emigrant

# %% [markdown]
# *I am interested in data science to be more popular at parties.*

# %% [markdown]
# ### H3 in Cell 5 we add *int*

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# here's | a | **table**
# --- | --- | ---
# `with` | a | **horizontal rule**
# and | A | [https://www.windy.com/]
